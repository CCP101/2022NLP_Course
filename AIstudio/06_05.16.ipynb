# %% [markdown]
# # 作业说明：
# **✓代码跑通**
#
# 请大家根据课上所学内容，在 VGGNet类中补全代码，构造VGG网络，保证程序跑通。在VGG构造成功的基础上，可尝试构造其他网络。
#
# **✓调优**
#
# 思考并动手进行调优，以在验证集上的准确率为评价指标，验证集上准确率越高，得分越高！

# %% [markdown]
# # **任务描述：**
#
#
# 如何根据据图像的视觉内容为图像赋予一个语义类别（例如，教室、街道等）是图像场景分类的目标，也是图像检索、图像内容分析和目标识别等问题的基础。但由于图片的尺度、角度、光照等多样性以及场景定义的复杂性，场景分类一直是计算机视觉中的一个挑战性问题。
#
# <br/>
#
# **本实践旨在通过一个场景分类的案列，让大家理解和掌握如何使用飞桨动态图搭建一个经典的卷积神经网络。**
#
# <br/>
#
# **特别提示：本实践所用数据集均来自互联网，请勿用于商务用途。**

# %%
import os
import zipfile
import random
import json
import paddle
import sys
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from paddle.io import Dataset

# %%
'''
参数配置
'''
train_parameters = {
    "input_size": [3, 224, 224],                              #输入图片的shape
    "class_dim": -1,                                          #分类数
    "src_path":"/home/aistudio/data/data77642/Chinese Medicine.zip",    #原始数据集路径
    "target_path":"/home/aistudio/data/",                     #要解压的路径
    "train_list_path": "/home/aistudio/data/train.txt",       #train.txt路径
    "eval_list_path": "/home/aistudio/data/eval.txt",         #eval.txt路径
    "readme_path": "/home/aistudio/data/readme.json",         #readme.json路径
    "label_dict":{},                                          #标签字典
    "num_epochs": 80,                                         #训练轮数
    "train_batch_size": 16,                                  #训练时每个批次的大小
    "skip_steps": 10,
    "save_steps": 30, 
    "learning_strategy": {                                    #优化函数相关的配置
        "lr": 0.0001                                          #超参数学习率
    },
    "checkpoints": "/home/aistudio/work/checkpoints"          #保存的路径

}

# %% [markdown]
# # **一、数据准备**
#
# （1）解压原始数据集
#
# （2）按照比例划分训练集与验证集
#
# （3）乱序，生成数据列表
#
# （4）构造训练数据集提供器和验证数据集提供器

# %%
def unzip_data(src_path,target_path):
    '''
    解压原始数据集，将src_path路径下的zip包解压至target_path目录下
    '''
    if(not os.path.isdir(target_path + "Chinese Medicine")):     
        z = zipfile.ZipFile(src_path, 'r')
        z.extractall(path=target_path)
        z.close()

# %%
def get_data_list(target_path,train_list_path,eval_list_path):
    '''
    生成数据列表
    '''
    #存放所有类别的信息
    class_detail = []
    #获取所有类别保存的文件夹名称
    data_list_path=target_path+"Chinese Medicine/"
    class_dirs = os.listdir(data_list_path)  
    #总的图像数量
    all_class_images = 0
    #存放类别标签
    class_label=0
    #存放类别数目
    class_dim = 0
    #存储要写进eval.txt和train.txt中的内容
    trainer_list=[]
    eval_list=[]
    #读取每个类别，['river', 'lawn','church','ice','desert']
    for class_dir in class_dirs:
        if class_dir != ".DS_Store":
            class_dim += 1
            #每个类别的信息
            class_detail_list = {}
            eval_sum = 0
            trainer_sum = 0
            #统计每个类别有多少张图片
            class_sum = 0
            #获取类别路径 
            path = data_list_path  + class_dir
            # 获取所有图片
            img_paths = os.listdir(path)
            for img_path in img_paths:                                  # 遍历文件夹下的每个图片
                name_path = path + '/' + img_path                       # 每张图片的路径
                if class_sum % 8 == 0:                                  # 每8张图片取一个做验证数据
                    eval_sum += 1                                       # test_sum为测试数据的数目
                    eval_list.append(name_path + "\t%d" % class_label + "\n")
                else:
                    trainer_sum += 1 
                    trainer_list.append(name_path + "\t%d" % class_label + "\n")#trainer_sum测试数据的数目
                class_sum += 1                                          #每类图片的数目
                all_class_images += 1                                   #所有类图片的数目
             
            # 说明的json文件的class_detail数据
            class_detail_list['class_name'] = class_dir             #类别名称
            class_detail_list['class_label'] = class_label          #类别标签
            class_detail_list['class_eval_images'] = eval_sum       #该类数据的测试集数目
            class_detail_list['class_trainer_images'] = trainer_sum #该类数据的训练集数目
            class_detail.append(class_detail_list)  
            #初始化标签列表
            train_parameters['label_dict'][str(class_label)] = class_dir
            class_label += 1 
            
    #初始化分类数
    train_parameters['class_dim'] = class_dim
  
    #乱序  
    random.shuffle(eval_list)
    with open(eval_list_path, 'a') as f:
        for eval_image in eval_list:
            f.write(eval_image) 
            
    random.shuffle(trainer_list)
    with open(train_list_path, 'a') as f2:
        for train_image in trainer_list:
            f2.write(train_image) 

    # 说明的json文件信息
    readjson = {}
    readjson['all_class_name'] = data_list_path                  #文件父目录
    readjson['all_class_images'] = all_class_images
    readjson['class_detail'] = class_detail
    jsons = json.dumps(readjson, sort_keys=True, indent=4, separators=(',', ': '))
    with open(train_parameters['readme_path'],'w') as f:
        f.write(jsons)
    print ('生成数据列表完成！')

# %%
'''
参数初始化
'''
src_path=train_parameters['src_path']
target_path=train_parameters['target_path']
train_list_path=train_parameters['train_list_path']
eval_list_path=train_parameters['eval_list_path']

'''
解压原始数据到指定路径
'''
unzip_data(src_path,target_path)

'''
划分训练集与验证集，乱序，生成数据列表
'''
#每次生成数据列表前，首先清空train.txt和eval.txt
with open(train_list_path, 'w') as f: 
    f.seek(0)
    f.truncate() 
with open(eval_list_path, 'w') as f: 
    f.seek(0)
    f.truncate() 
    
#生成数据列表   
get_data_list(target_path,train_list_path,eval_list_path)
# Out:
# 生成数据列表完成！

# %%
class dataset(Dataset):
    def __init__(self, data_path, mode='train'):
        """
        数据读取器
        :param data_path: 数据集所在路径
        :param mode: train or eval
        """
        super().__init__()
        self.data_path = data_path
        self.img_paths = []
        self.labels = []

        if mode == 'train':
            with open(os.path.join(self.data_path, "train.txt"), "r", encoding="utf-8") as f:
                self.info = f.readlines()
            for img_info in self.info:
                img_path, label = img_info.strip().split('\t')
                self.img_paths.append(img_path)
                self.labels.append(int(label))

        else:
            with open(os.path.join(self.data_path, "eval.txt"), "r", encoding="utf-8") as f:
                self.info = f.readlines()
            for img_info in self.info:
                img_path, label = img_info.strip().split('\t')
                self.img_paths.append(img_path)
                self.labels.append(int(label))


    def __getitem__(self, index):
        """
        获取一组数据
        :param index: 文件索引号
        :return:
        """
        # 第一步打开图像文件并获取label值
        img_path = self.img_paths[index]
        img = Image.open(img_path)
        if img.mode != 'RGB':
            img = img.convert('RGB') 
        img = img.resize((224, 224), Image.BILINEAR)
        img = np.array(img).astype('float32')
        img = img.transpose((2, 0, 1)) / 255
        label = self.labels[index]
        label = np.array([label], dtype="int64")
        return img, label

    def print_sample(self, index: int = 0):
        print("文件名", self.img_paths[index], "\t标签值", self.labels[index])

    def __len__(self):
        return len(self.img_paths)

# %%
#训练数据加载
train_dataset = dataset('/home/aistudio/data',mode='train')
train_loader = paddle.io.DataLoader(train_dataset, batch_size=16, shuffle=True)
#测试数据加载
eval_dataset = dataset('/home/aistudio/data',mode='eval')
eval_loader = paddle.io.DataLoader(eval_dataset, batch_size = 8, shuffle=False)

# %%
train_dataset.print_sample(200)
print(train_dataset.__len__())
eval_dataset.print_sample(0)
print(eval_dataset.__len__())
print(eval_dataset.__getitem__(10)[0].shape)
print(eval_dataset.__getitem__(10)[1].shape)
# Out:
# 文件名 /home/aistudio/data/Chinese Medicine/gouqi/u=94477225,462162253&fm=26&gp=0.jpg 	标签值 1
# 787
# 文件名 /home/aistudio/data/Chinese Medicine/jinyinhua/jyh_38.jpg 	标签值 3
# 115
# (3, 224, 224)
# (1,)

# %% [markdown]
# # **二、模型配置**
#
# ![](https://ai-studio-static-online.cdn.bcebos.com/9ca0744272b0449186f766afcabadd598e24679088a4438dafede05a71b7c141)
#
# VGG的核心是五组卷积操作，每两组之间做Max-Pooling空间降维。同一组内采用多次连续的3X3卷积，卷积核的数目由较浅组的64增多到最深组的512，同一组内的卷积核数目是一样的。卷积之后接两层全连 接层，之后是分类层。由于每组内卷积层的不同，有11、13、16、19层这几种模型，上图展示一个16层的网络结构。

# %%
class ConvPool(paddle.nn.Layer):
    '''卷积+池化'''
    def __init__(self,
                 num_channels,#1
                 num_filters, #2
                 filter_size,#3
                 pool_size,#4
                 pool_stride,#5
                 groups,#6
                 conv_stride=1, 
                 conv_padding=1,
                 ):
        super(ConvPool, self).__init__()  
        self._conv2d_list = []

        for i in range(groups):
            conv2d = self.add_sublayer(   #添加子层实例
                'bb_%d' % i,
                paddle.nn.Conv2D(         # layer
                in_channels=num_channels, #通道数
                out_channels=num_filters,   #卷积核个数
                kernel_size=filter_size,   #卷积核大小
                stride=conv_stride,        #步长
                padding = conv_padding,    #padding
                )
            )
            num_channels = num_filters
            
            self._conv2d_list.append(conv2d)

        self._pool2d = paddle.nn.MaxPool2D(
            kernel_size=pool_size,           #池化核大小
            stride=pool_stride               #池化步长
            )
        print(self._conv2d_list)





    def forward(self, inputs):
      x = inputs
      for conv in self._conv2d_list:
         x = conv(x)
         x = paddle.nn.functional.relu(x)
      x = self._pool2d(x)
      return x

# %%
class VGGNet(paddle.nn.Layer):
  
    def __init__(self):
        super(VGGNet, self).__init__()       
        self.convpool01 = ConvPool(
            3, 64, 3, 2, 2, 2)  #3:通道数，64：卷积核个数，3:卷积核大小，2:池化核大小，2:池化步长，2:连续卷积个数
        self.convpool02 = ConvPool(
            64, 128, 3, 2, 2, 2)
        self.convpool03 = ConvPool(
            128, 256, 3, 2, 2, 3) 
        self.convpool04 = ConvPool(
            256, 512, 3, 2, 2, 3)
        self.convpool05 = ConvPool(
            512, 512, 3, 2, 2, 3)       
        self.pool_5_shape = 512 * 7* 7
        self.fc01 = paddle.nn.Linear(self.pool_5_shape, 4096)
        self.fc02 = paddle.nn.Linear(4096, 4096)
        self.fc03 = paddle.nn.Linear(4096, train_parameters['class_dim'])

    def forward(self, inputs, label=None):
        # print('input_shape:', inputs.shape) #[8, 3, 224, 224]
        """前向计算"""
        out = self.convpool01(inputs)
        # print('convpool01_shape:', out.shape)           #[8, 64, 112, 112]
        out = self.convpool02(out)
        # print('convpool02_shape:', out.shape)           #[8, 128, 56, 56]
        out = self.convpool03(out)
        # print('convpool03_shape:', out.shape)           #[8, 256, 28, 28]
        out = self.convpool04(out)
        # print('convpool04_shape:', out.shape)           #[8, 512, 14, 14]
        out = self.convpool05(out)
        # print('convpool05_shape:', out.shape)           #[8, 512, 7, 7]         

        out = paddle.reshape(out, shape=[-1, 512*7*7])
        out = self.fc01(out)
        out = self.fc02(out)
        out = self.fc03(out)
        
        if label is not None:
            acc = paddle.metric.accuracy(input=out, label=label)
            return out, acc
        else:
            return out

# %% [markdown]
# # **三、模型训练 && 四、模型评估**

# %%
def draw_process(title,color,iters,data,label):
    plt.title(title, fontsize=24)
    plt.xlabel("iter", fontsize=20)
    plt.ylabel(label, fontsize=20)
    plt.plot(iters, data,color=color,label=label) 
    plt.legend()
    plt.grid()
    plt.show()

# %%
print(train_parameters['class_dim'])
print(train_parameters['label_dict'])
# Out:
# 5
# {'0': 'huaihua', '1': 'gouqi', '2': 'baihe', '3': 'jinyinhua', '4': 'dangshen'}

# %%
model = VGGNet()
model.train()
cross_entropy = paddle.nn.CrossEntropyLoss()
optimizer = paddle.optimizer.Adam(learning_rate=train_parameters['learning_strategy']['lr'],
                                  parameters=model.parameters()) 

steps = 0
Iters, total_loss, total_acc = [], [], []

for epo in range(train_parameters['num_epochs']):
    for _, data in enumerate(train_loader()):
        steps += 1
        x_data = data[0]
        y_data = data[1]
        predicts, acc = model(x_data, y_data)
        loss = cross_entropy(predicts, y_data)
        loss.backward()
        optimizer.step()
        optimizer.clear_grad()
        if steps % train_parameters["skip_steps"] == 0:
            Iters.append(steps)
            total_loss.append(loss.numpy()[0])
            total_acc.append(acc.numpy()[0])
            #打印中间过程
            print('epo: {}, step: {}, loss is: {}, acc is: {}'\
                  .format(epo, steps, loss.numpy(), acc.numpy()))
        #保存模型参数
        if steps % train_parameters["save_steps"] == 0:
            save_path = train_parameters["checkpoints"]+"/"+"save_dir_" + "100" + '.pdparams'
            print('save model to: ' + save_path)
            paddle.save(model.state_dict(),save_path)
paddle.save(model.state_dict(),train_parameters["checkpoints"]+"/"+"save_dir_final.pdparams")
draw_process("trainning loss","red",Iters,total_loss,"trainning loss")
draw_process("trainning acc","green",Iters,total_acc,"trainning acc")
# Out:
# W0516 13:33:37.057952   150 device_context.cc:362] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 11.2, Runtime API Version: 10.1
# W0516 13:33:37.062744   150 device_context.cc:372] device: 0, cuDNN Version: 7.6.
# [Conv2D(3, 64, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(64, 64, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(64, 128, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(128, 128, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(128, 256, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(256, 256, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(256, 256, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(256, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/dataloader/dataloader_iter.py:89: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if isinstance(slot[0], (np.ndarray, np.bool, numbers.Number)):
# epo: 0, step: 10, loss is: [1.7869835], acc is: [0.125]
# epo: 0, step: 20, loss is: [1.5442077], acc is: [0.1875]
# epo: 0, step: 30, loss is: [1.3748085], acc is: [0.25]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 0, step: 40, loss is: [1.1119606], acc is: [0.3125]
# epo: 0, step: 50, loss is: [1.1545115], acc is: [0.33333334]
# epo: 1, step: 60, loss is: [1.5966561], acc is: [0.25]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 1, step: 70, loss is: [1.0004631], acc is: [0.5625]
# epo: 1, step: 80, loss is: [0.7210519], acc is: [0.625]
# epo: 1, step: 90, loss is: [0.9111076], acc is: [0.5625]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 1, step: 100, loss is: [0.8796446], acc is: [0.6666667]
# epo: 2, step: 110, loss is: [0.8856419], acc is: [0.625]
# epo: 2, step: 120, loss is: [0.6467419], acc is: [0.8125]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 2, step: 130, loss is: [1.0627164], acc is: [0.5]
# epo: 2, step: 140, loss is: [0.84380186], acc is: [0.625]
# epo: 2, step: 150, loss is: [1.1204462], acc is: [0.33333334]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 3, step: 160, loss is: [1.047482], acc is: [0.5]
# epo: 3, step: 170, loss is: [0.7305699], acc is: [0.5625]
# epo: 3, step: 180, loss is: [1.218476], acc is: [0.375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 3, step: 190, loss is: [0.58243674], acc is: [0.8125]
# epo: 3, step: 200, loss is: [0.5847385], acc is: [0.6666667]
# epo: 4, step: 210, loss is: [1.0429807], acc is: [0.625]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 4, step: 220, loss is: [0.92358124], acc is: [0.5625]
# epo: 4, step: 230, loss is: [0.7086138], acc is: [0.5625]
# epo: 4, step: 240, loss is: [0.5712373], acc is: [0.75]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 4, step: 250, loss is: [1.4525893], acc is: [0.33333334]
# epo: 5, step: 260, loss is: [0.6880753], acc is: [0.5625]
# epo: 5, step: 270, loss is: [0.36328954], acc is: [0.875]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 5, step: 280, loss is: [0.94635534], acc is: [0.5625]
# epo: 5, step: 290, loss is: [0.8929156], acc is: [0.6875]
# epo: 5, step: 300, loss is: [0.3338975], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 6, step: 310, loss is: [0.5800003], acc is: [0.75]
# epo: 6, step: 320, loss is: [0.6295874], acc is: [0.75]
# epo: 6, step: 330, loss is: [1.5300403], acc is: [0.3125]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 6, step: 340, loss is: [0.9757535], acc is: [0.5625]
# epo: 6, step: 350, loss is: [0.02468296], acc is: [1.]
# epo: 7, step: 360, loss is: [0.3778085], acc is: [0.8125]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 7, step: 370, loss is: [0.59604776], acc is: [0.6875]
# epo: 7, step: 380, loss is: [0.9045001], acc is: [0.5]
# epo: 7, step: 390, loss is: [0.843034], acc is: [0.625]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 7, step: 400, loss is: [1.4349644], acc is: [0.33333334]
# epo: 8, step: 410, loss is: [0.4468484], acc is: [0.75]
# epo: 8, step: 420, loss is: [0.44688156], acc is: [0.75]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 8, step: 430, loss is: [0.70531225], acc is: [0.75]
# epo: 8, step: 440, loss is: [1.0169995], acc is: [0.5]
# epo: 8, step: 450, loss is: [0.3938504], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 9, step: 460, loss is: [0.5558054], acc is: [0.75]
# epo: 9, step: 470, loss is: [0.62055755], acc is: [0.6875]
# epo: 9, step: 480, loss is: [0.48958337], acc is: [0.875]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 9, step: 490, loss is: [1.0057938], acc is: [0.5]
# epo: 9, step: 500, loss is: [0.6266617], acc is: [0.6666667]
# epo: 10, step: 510, loss is: [0.40493], acc is: [0.6875]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 10, step: 520, loss is: [0.52323276], acc is: [0.8125]
# epo: 10, step: 530, loss is: [0.71307695], acc is: [0.75]
# epo: 10, step: 540, loss is: [0.80766535], acc is: [0.5625]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 10, step: 550, loss is: [0.5068573], acc is: [0.6666667]
# epo: 11, step: 560, loss is: [0.5391333], acc is: [0.75]
# epo: 11, step: 570, loss is: [0.29938698], acc is: [0.8125]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 11, step: 580, loss is: [0.9150051], acc is: [0.6875]
# epo: 11, step: 590, loss is: [0.4231308], acc is: [0.875]
# epo: 11, step: 600, loss is: [0.17736803], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 12, step: 610, loss is: [0.08247426], acc is: [1.]
# epo: 12, step: 620, loss is: [0.4211439], acc is: [0.875]
# epo: 12, step: 630, loss is: [0.41838944], acc is: [0.8125]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 12, step: 640, loss is: [0.7267478], acc is: [0.6875]
# epo: 12, step: 650, loss is: [0.5388751], acc is: [0.6666667]
# epo: 13, step: 660, loss is: [0.7423334], acc is: [0.625]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 13, step: 670, loss is: [0.30928952], acc is: [0.8125]
# epo: 13, step: 680, loss is: [0.64091206], acc is: [0.75]
# epo: 13, step: 690, loss is: [0.48329306], acc is: [0.75]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 13, step: 700, loss is: [0.5115599], acc is: [0.6666667]
# epo: 14, step: 710, loss is: [0.5197961], acc is: [0.75]
# epo: 14, step: 720, loss is: [0.29308352], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 14, step: 730, loss is: [0.6027388], acc is: [0.8125]
# epo: 14, step: 740, loss is: [0.39248967], acc is: [0.8125]
# epo: 14, step: 750, loss is: [0.], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 15, step: 760, loss is: [0.3982372], acc is: [0.8125]
# epo: 15, step: 770, loss is: [0.34934926], acc is: [0.875]
# epo: 15, step: 780, loss is: [0.6657857], acc is: [0.6875]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 15, step: 790, loss is: [0.50166625], acc is: [0.75]
# epo: 15, step: 800, loss is: [0.38459152], acc is: [0.6666667]
# epo: 16, step: 810, loss is: [0.21061385], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 16, step: 820, loss is: [0.53965557], acc is: [0.5625]
# epo: 16, step: 830, loss is: [0.36435628], acc is: [0.875]
# epo: 16, step: 840, loss is: [0.28822988], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 16, step: 850, loss is: [0.01296255], acc is: [1.]
# epo: 17, step: 860, loss is: [0.5280179], acc is: [0.75]
# epo: 17, step: 870, loss is: [0.31020433], acc is: [0.875]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 17, step: 880, loss is: [0.18096738], acc is: [0.9375]
# epo: 17, step: 890, loss is: [0.10823345], acc is: [0.9375]
# epo: 17, step: 900, loss is: [0.12318635], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 18, step: 910, loss is: [0.8514794], acc is: [0.6875]
# epo: 18, step: 920, loss is: [0.4107646], acc is: [0.8125]
# epo: 18, step: 930, loss is: [0.29919553], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 18, step: 940, loss is: [0.22617444], acc is: [0.9375]
# epo: 18, step: 950, loss is: [0.2124159], acc is: [1.]
# epo: 19, step: 960, loss is: [0.15194489], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 19, step: 970, loss is: [0.24447863], acc is: [0.9375]
# epo: 19, step: 980, loss is: [0.11280674], acc is: [1.]
# epo: 19, step: 990, loss is: [0.39189374], acc is: [0.8125]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 19, step: 1000, loss is: [1.0478843], acc is: [0.33333334]
# epo: 20, step: 1010, loss is: [0.6023977], acc is: [0.6875]
# epo: 20, step: 1020, loss is: [0.4214301], acc is: [0.8125]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 20, step: 1030, loss is: [0.44032004], acc is: [0.8125]
# epo: 20, step: 1040, loss is: [0.71990407], acc is: [0.75]
# epo: 20, step: 1050, loss is: [0.9545609], acc is: [0.6666667]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 21, step: 1060, loss is: [0.5640822], acc is: [0.75]
# epo: 21, step: 1070, loss is: [0.2608657], acc is: [0.875]
# epo: 21, step: 1080, loss is: [0.7885548], acc is: [0.6875]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 21, step: 1090, loss is: [0.11130033], acc is: [1.]
# epo: 21, step: 1100, loss is: [1.348141], acc is: [0.6666667]
# epo: 22, step: 1110, loss is: [0.24093258], acc is: [0.875]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 22, step: 1120, loss is: [0.15525664], acc is: [0.9375]
# epo: 22, step: 1130, loss is: [0.19539231], acc is: [0.875]
# epo: 22, step: 1140, loss is: [0.2101391], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 22, step: 1150, loss is: [0.05825061], acc is: [1.]
# epo: 23, step: 1160, loss is: [0.1473883], acc is: [0.875]
# epo: 23, step: 1170, loss is: [0.2723878], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 23, step: 1180, loss is: [0.1901209], acc is: [0.875]
# epo: 23, step: 1190, loss is: [0.488489], acc is: [0.8125]
# epo: 23, step: 1200, loss is: [0.17915338], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 24, step: 1210, loss is: [0.10325883], acc is: [0.9375]
# epo: 24, step: 1220, loss is: [0.07659559], acc is: [1.]
# epo: 24, step: 1230, loss is: [0.11537462], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 24, step: 1240, loss is: [0.1466582], acc is: [0.9375]
# epo: 24, step: 1250, loss is: [0.17629811], acc is: [1.]
# epo: 25, step: 1260, loss is: [0.23772767], acc is: [0.8125]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 25, step: 1270, loss is: [0.34172457], acc is: [0.875]
# epo: 25, step: 1280, loss is: [0.06225807], acc is: [1.]
# epo: 25, step: 1290, loss is: [0.16763991], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 25, step: 1300, loss is: [0.10107119], acc is: [1.]
# epo: 26, step: 1310, loss is: [0.18815772], acc is: [0.9375]
# epo: 26, step: 1320, loss is: [0.10876264], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 26, step: 1330, loss is: [0.07417234], acc is: [0.9375]
# epo: 26, step: 1340, loss is: [0.28582776], acc is: [0.8125]
# epo: 26, step: 1350, loss is: [0.04304481], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 27, step: 1360, loss is: [0.17089629], acc is: [0.9375]
# epo: 27, step: 1370, loss is: [0.0983051], acc is: [0.9375]
# epo: 27, step: 1380, loss is: [0.09628687], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 27, step: 1390, loss is: [0.4450446], acc is: [0.875]
# epo: 27, step: 1400, loss is: [0.01235003], acc is: [1.]
# epo: 28, step: 1410, loss is: [0.15651837], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 28, step: 1420, loss is: [0.01319432], acc is: [1.]
# epo: 28, step: 1430, loss is: [0.13093896], acc is: [1.]
# epo: 28, step: 1440, loss is: [0.12721828], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 28, step: 1450, loss is: [0.33104202], acc is: [0.6666667]
# epo: 29, step: 1460, loss is: [0.06838401], acc is: [1.]
# epo: 29, step: 1470, loss is: [0.1178619], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 29, step: 1480, loss is: [0.02571038], acc is: [1.]
# epo: 29, step: 1490, loss is: [0.05150869], acc is: [1.]
# epo: 29, step: 1500, loss is: [1.986821e-07], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 30, step: 1510, loss is: [0.01342528], acc is: [1.]
# epo: 30, step: 1520, loss is: [0.08221633], acc is: [0.9375]
# epo: 30, step: 1530, loss is: [0.03140377], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 30, step: 1540, loss is: [0.13075721], acc is: [1.]
# epo: 30, step: 1550, loss is: [2.1651201], acc is: [0.]
# epo: 31, step: 1560, loss is: [1.2350366], acc is: [0.5625]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 31, step: 1570, loss is: [0.17500988], acc is: [0.9375]
# epo: 31, step: 1580, loss is: [0.10515223], acc is: [0.9375]
# epo: 31, step: 1590, loss is: [0.02549136], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 31, step: 1600, loss is: [0.5654744], acc is: [0.6666667]
# epo: 32, step: 1610, loss is: [0.38962695], acc is: [0.8125]
# epo: 32, step: 1620, loss is: [0.30330262], acc is: [0.875]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 32, step: 1630, loss is: [0.07180113], acc is: [0.9375]
# epo: 32, step: 1640, loss is: [0.23476607], acc is: [0.9375]
# epo: 32, step: 1650, loss is: [0.06814389], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 33, step: 1660, loss is: [0.04069223], acc is: [1.]
# epo: 33, step: 1670, loss is: [0.00223743], acc is: [1.]
# epo: 33, step: 1680, loss is: [1.8851409], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 33, step: 1690, loss is: [1.535003], acc is: [0.5625]
# epo: 33, step: 1700, loss is: [0.02251223], acc is: [1.]
# epo: 34, step: 1710, loss is: [0.15655887], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 34, step: 1720, loss is: [0.04532504], acc is: [1.]
# epo: 34, step: 1730, loss is: [0.00299546], acc is: [1.]
# epo: 34, step: 1740, loss is: [0.07481518], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 34, step: 1750, loss is: [0.00228837], acc is: [1.]
# epo: 35, step: 1760, loss is: [0.06557681], acc is: [1.]
# epo: 35, step: 1770, loss is: [0.27010337], acc is: [0.875]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 35, step: 1780, loss is: [0.05058673], acc is: [1.]
# epo: 35, step: 1790, loss is: [0.08612555], acc is: [0.9375]
# epo: 35, step: 1800, loss is: [0.0026436], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 36, step: 1810, loss is: [0.00279202], acc is: [1.]
# epo: 36, step: 1820, loss is: [0.29249555], acc is: [0.9375]
# epo: 36, step: 1830, loss is: [0.18649249], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 36, step: 1840, loss is: [0.03045451], acc is: [1.]
# epo: 36, step: 1850, loss is: [0.09236377], acc is: [1.]
# epo: 37, step: 1860, loss is: [0.00993682], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 37, step: 1870, loss is: [0.004387], acc is: [1.]
# epo: 37, step: 1880, loss is: [0.0045381], acc is: [1.]
# epo: 37, step: 1890, loss is: [0.00612709], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 37, step: 1900, loss is: [0.00869501], acc is: [1.]
# epo: 38, step: 1910, loss is: [0.00079016], acc is: [1.]
# epo: 38, step: 1920, loss is: [0.00434042], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 38, step: 1930, loss is: [0.13204566], acc is: [0.9375]
# epo: 38, step: 1940, loss is: [0.0029237], acc is: [1.]
# epo: 38, step: 1950, loss is: [0.00083655], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 39, step: 1960, loss is: [0.06108808], acc is: [0.9375]
# epo: 39, step: 1970, loss is: [0.00396749], acc is: [1.]
# epo: 39, step: 1980, loss is: [0.03092316], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 39, step: 1990, loss is: [0.01489704], acc is: [1.]
# epo: 39, step: 2000, loss is: [0.00359607], acc is: [1.]
# epo: 40, step: 2010, loss is: [0.00011064], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 40, step: 2020, loss is: [0.00112076], acc is: [1.]
# epo: 40, step: 2030, loss is: [0.00039616], acc is: [1.]
# epo: 40, step: 2040, loss is: [0.01467762], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 40, step: 2050, loss is: [0.00141044], acc is: [1.]
# epo: 41, step: 2060, loss is: [0.00215455], acc is: [1.]
# epo: 41, step: 2070, loss is: [0.06759491], acc is: [0.9375]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo:
-05], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 72, step: 3640, loss is: [3.4731325e-05], acc is: [1.]
# epo: 72, step: 3650, loss is: [1.48213585e-05], acc is: [1.]
# epo: 73, step: 3660, loss is: [1.8104707e-06], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 73, step: 3670, loss is: [2.5440248e-05], acc is: [1.]
# epo: 73, step: 3680, loss is: [1.7351338e-05], acc is: [1.]
# epo: 73, step: 3690, loss is: [5.3866643e-06], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 73, step: 3700, loss is: [7.9472855e-08], acc is: [1.]
# epo: 74, step: 3710, loss is: [4.775754e-06], acc is: [1.]
# epo: 74, step: 3720, loss is: [1.7149823e-05], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 74, step: 3730, loss is: [2.4644449e-05], acc is: [1.]
# epo: 74, step: 3740, loss is: [1.3335693e-05], acc is: [1.]
# epo: 74, step: 3750, loss is: [0.], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 75, step: 3760, loss is: [4.007047e-05], acc is: [1.]
# epo: 75, step: 3770, loss is: [4.7683097e-06], acc is: [1.]
# epo: 75, step: 3780, loss is: [2.5010015e-05], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 75, step: 3790, loss is: [5.5580404e-06], acc is: [1.]
# epo: 75, step: 3800, loss is: [0.], acc is: [1.]
# epo: 76, step: 3810, loss is: [7.793031e-06], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 76, step: 3820, loss is: [1.3783481e-06], acc is: [1.]
# epo: 76, step: 3830, loss is: [4.5149463e-06], acc is: [1.]
# epo: 76, step: 3840, loss is: [1.2144362e-06], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 76, step: 3850, loss is: [4.1325634e-06], acc is: [1.]
# epo: 77, step: 3860, loss is: [7.785593e-06], acc is: [1.]
# epo: 77, step: 3870, loss is: [1.256854e-05], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 77, step: 3880, loss is: [1.3082108e-05], acc is: [1.]
# epo: 77, step: 3890, loss is: [4.365985e-06], acc is: [1.]
# epo: 77, step: 3900, loss is: [7.9472855e-08], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 78, step: 3910, loss is: [1.5474276e-05], acc is: [1.]
# epo: 78, step: 3920, loss is: [2.1159524e-06], acc is: [1.]
# epo: 78, step: 3930, loss is: [8.0466117e-07], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 78, step: 3940, loss is: [8.26226e-06], acc is: [1.]
# epo: 78, step: 3950, loss is: [0.], acc is: [1.]
# epo: 79, step: 3960, loss is: [1.9943318e-05], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 79, step: 3970, loss is: [7.204439e-06], acc is: [1.]
# epo: 79, step: 3980, loss is: [3.8082613e-05], acc is: [1.]
# epo: 79, step: 3990, loss is: [2.4800707e-05], acc is: [1.]
# save model to: /home/aistudio/work/checkpoints/save_dir_100.pdparams
# epo: 79, step: 4000, loss is: [1.4305097e-06], acc is: [1.]
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2349: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   if isinstance(obj, collections.Iterator):
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:2366: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   return list(data) if isinstance(data, collections.MappingView) else data

# %%
'''
模型预测
'''
model__state_dict = paddle.load('work/checkpoints/save_dir_final.pdparams')
model_eval = VGGNet()
model_eval.set_state_dict(model__state_dict) 
model_eval.eval()
accs = []

for _, data in enumerate(eval_loader()):
    x_data = data[0]
    y_data = data[1]
    predicts = model_eval(x_data)
    acc = paddle.metric.accuracy(predicts, y_data)
    accs.append(acc.numpy()[0])
print('模型在验证集上的准确率为：',np.mean(accs))
# Out:
# [Conv2D(3, 64, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(64, 64, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(64, 128, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(128, 128, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(128, 256, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(256, 256, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(256, 256, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(256, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# 模型在验证集上的准确率为： 0.825

# %% [markdown]
# # **五、模型预测**

# %%
import os
import zipfile

def unzip_infer_data(src_path,target_path):
    '''
    解压预测数据集
    '''
    if(not os.path.isdir(target_path + "Chinese Medicine Infer")):     
    # if(not os.path.isdir(target_path + "Chinese Medicine")):  
        z = zipfile.ZipFile(src_path, 'r')
        z.extractall(path=target_path)
        z.close()


def load_image(img_path):
    '''
    预测图片预处理
    '''
    img = Image.open(img_path) 
    if img.mode != 'RGB': 
        img = img.convert('RGB') 
    img = img.resize((224, 224), Image.BILINEAR)
    img = np.array(img).astype('float32') 
    img = img.transpose((2, 0, 1)) / 255 # HWC to CHW 及归一化
    return img


infer_src_path = '/home/aistudio/data/data77642/Chinese Medicine Infer.zip'
# infer_src_path = '/home/aistudio/data/data77642/Chinese Medicine.zip'
infer_dst_path = '/home/aistudio/data/'
unzip_infer_data(infer_src_path,infer_dst_path)

label_dic = train_parameters['label_dict']

# %%
model__state_dict = paddle.load('work/checkpoints/save_dir_final.pdparams')
model_predict = VGGNet()
model_predict.set_state_dict(model__state_dict) 
model_predict.eval()
infer_imgs_path = os.listdir(infer_dst_path+"Chinese Medicine Infer/")
print(infer_imgs_path)
for infer_img_path in infer_imgs_path:
    infer_img = load_image(infer_dst_path+"Chinese Medicine Infer/"+infer_img_path)
    infer_img = infer_img[np.newaxis,:, : ,:]  #reshape(-1,3,224,224)
    infer_img = paddle.to_tensor(infer_img)
    result = model_predict(infer_img)
    lab = np.argmax(result.numpy())
    print("样本: {},被预测为:{}".format(infer_img_path,label_dic[str(lab)]))
# Out:
# [Conv2D(3, 64, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(64, 64, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(64, 128, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(128, 128, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(128, 256, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(256, 256, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(256, 256, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(256, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# [Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW), Conv2D(512, 512, kernel_size=[3, 3], padding=1, data_format=NCHW)]
# ['dangshen (15).jpg', 'jinyinhua (63).jpg', 'gouqi (9).jpg', 'jinyinhua (131).jpg', 'baihe (9).jpg', 'jinyinhua (62).jpg', 'baihe (4).jpg', 'baihe (1).jpg', 'baihe (20).jpg', 'baihe (7).jpg', 'gouqi (1).jpg', 'gouqi (4).gif', 'tianma (7).jpg', 'dangshen (12).jpg', 'tianma (5).jpg', 'gouqi (9).gif', 'tianma (8).jpg', 'baihe (2).jpg', 'dangshen (1).jpg', 'gouqi (3).gif', 'jinyinhua (123).jpg', 'gouqi (8).gif', 'gouqi (2).gif', 'dangshen (14).jpg', 'tianma (11).jpg', 'tianma (13).jpg', 'dangshen (16).jpg', 'dangshen (9).jpg', 'tianma (19).jpg', 'gouqi (10).jpg', 'jinyinhua (61).jpg', 'baihe (10).jpg', 'tianma (2).jpg', 'tianma (12).jpg', 'tianma (9).jpg', 'tianma (20).jpg', 'baihe (13).jpg', 'dangshen (7).jpg', 'gouqi (5).gif', 'tianma (16).jpg', 'baihe (11).jpg', 'baihe (15).jpg', 'gouqi (6).jpg', 'jinyinhua (1).jpg', 'jinyinhua (132).jpg', 'jinyinhua (121).jpg', 'jinyinhua (128).jpg', 'dangshen (6).jpg', 'jinyinhua (60).jpg', 'baihe (8).jpg', 'dangshen (17).jpg', 'dangshen (5).jpg', 'jinyinhua (134).jpg', 'tianma (6).jpg', 'baihe (3).jpg', 'gouqi (4).jpg', 'tianma (4).jpg', 'baihe (14).jpg', 'dangshen (11).jpg', 'baihe (5).jpg', 'tianma (17).jpg', 'gouqi (1).gif', 'gouqi (6).gif', 'tianma (18).jpg', 'dangshen (20).jpg', 'dangshen (19).jpg', 'jinyinhua (113).jpg', 'tianma (1).jpg', 'tianma (3).jpg', 'jinyinhua (114).jpg', 'baihe (16).jpg', 'baihe (18).jpg', 'jinyinhua (115).jpg', 'dangshen (4).jpg', 'dangshen (18).jpg', 'jinyinhua (112).jpg', 'jinyinhua (130).jpg', 'gouqi (3).jpg', 'baihe (12).jpg', 'tianma (10).jpg', 'gouqi (5).jpg', 'dangshen (3).jpg', 'gouqi (8).jpg', 'baihe (17).jpg', 'dangshen (2).jpg', 'gouqi (2).jpg', 'gouqi (7).gif', 'tianma (14).jpg', 'dangshen (8).jpg', 'baihe (19).jpg', 'baihe (6).jpg', 'jinyinhua (133).jpg', 'gouqi (11).jpg', 'jinyinhua (129).jpg', 'dangshen (10).jpg', 'jinyinhua (122).jpg', 'jinyinhua (120).jpg', 'gouqi (7).jpg', 'tianma (15).jpg', 'dangshen (13).jpg']
# 样本: dangshen (15).jpg,被预测为:dangshen
# 样本: jinyinhua (63).jpg,被预测为:jinyinhua
# 样本: gouqi (9).jpg,被预测为:gouqi
# 样本: jinyinhua (131).jpg,被预测为:jinyinhua
# 样本: baihe (9).jpg,被预测为:huaihua
# 样本: jinyinhua (62).jpg,被预测为:jinyinhua
# 样本: baihe (4).jpg,被预测为:baihe
# 样本: baihe (1).jpg,被预测为:baihe
# 样本: baihe (20).jpg,被预测为:baihe
# 样本: baihe (7).jpg,被预测为:baihe
# 样本: gouqi (1).jpg,被预测为:gouqi
# 样本: gouqi (4).gif,被预测为:gouqi
# 样本: tianma (7).jpg,被预测为:baihe
# 样本: dangshen (12).jpg,被预测为:dangshen
# 样本: tianma (5).jpg,被预测为:baihe
# 样本: gouqi (9).gif,被预测为:gouqi
# 样本: tianma (8).jpg,被预测为:baihe
# 样本: baihe (2).jpg,被预测为:baihe
# 样本: dangshen (1).jpg,被预测为:dangshen
# 样本: gouqi (3).gif,被预测为:gouqi
# 样本: jinyinhua (123).jpg,被预测为:jinyinhua
# 样本: gouqi (8).gif,被预测为:gouqi
# 样本: gouqi (2).gif,被预测为:gouqi
# 样本: dangshen (14).jpg,被预测为:dangshen
# 样本: tianma (11).jpg,被预测为:baihe
# 样本: tianma (13).jpg,被预测为:baihe
# 样本: dangshen (16).jpg,被预测为:jinyinhua
# 样本: dangshen (9).jpg,被预测为:baihe
# 样本: tianma (19).jpg,被预测为:baihe
# 样本: gouqi (10).jpg,被预测为:gouqi
# 样本: jinyinhua (61).jpg,被预测为:jinyinhua
# 样本: baihe (10).jpg,被预测为:dangshen
# 样本: tianma (2).jpg,被预测为:baihe
# 样本: tianma (12).jpg,被预测为:baihe
# 样本: tianma (9).jpg,被预测为:baihe
# 样本: tianma (20).jpg,被预测为:baihe
# 样本: baihe (13).jpg,被预测为:baihe
# 样本: dangshen (7).jpg,被预测为:dangshen
# 样本: gouqi (5).gif,被预测为:gouqi
# 样本: tianma (16).jpg,被预测为:baihe
# 样本: baihe (11).jpg,被预测为:jinyinhua
# 样本: baihe (15).jpg,被预测为:baihe
# 样本: gouqi (6).jpg,被预测为:gouqi
# 样本: jinyinhua (1).jpg,被预测为:jinyinhua
# 样本: jinyinhua (132).jpg,被预测为:jinyinhua
# 样本: jinyinhua (121).jpg,被预测为:jinyinhua
# 样本: jinyinhua (128).jpg,被预测为:jinyinhua
# 样本: dangshen (6).jpg,被预测为:dangshen
# 样本: jinyinhua (60).jpg,被预测为:jinyinhua
# 样本: baihe (8).jpg,被预测为:baihe
# 样本: dangshen (17).jpg,被预测为:jinyinhua
# 样本: dangshen (5).jpg,被预测为:baihe
# 样本: jinyinhua (134).jpg,被预测为:jinyinhua
# 样本: tianma (6).jpg,被预测为:dangshen
# 样本: baihe (3).jpg,被预测为:baihe
# 样本: gouqi (4).jpg,被预测为:gouqi
# 样本: tianma (4).jpg,被预测为:baihe
# 样本: baihe (14).jpg,被预测为:baihe
# 样本: dangshen (11).jpg,被预测为:dangshen
# 样本: baihe (5).jpg,被预测为:baihe
# 样本: tianma (17).jpg,被预测为:baihe
# 样本: gouqi (1).gif,被预测为:gouqi
# 样本: gouqi (6).gif,被预测为:gouqi
# 样本: tianma (18).jpg,被预测为:baihe
# 样本: dangshen (20).jpg,被预测为:huaihua
# 样本: dangshen (19).jpg,被预测为:jinyinhua
# 样本: jinyinhua (113).jpg,被预测为:jinyinhua
# 样本: tianma (1).jpg,被预测为:baihe
# 样本: tianma (3).jpg,被预测为:baihe
# 样本: jinyinhua (114).jpg,被预测为:jinyinhua
# 样本: baihe (16).jpg,被预测为:baihe
# 样本: baihe (18).jpg,被预测为:baihe
# 样本: jinyinhua (115).jpg,被预测为:jinyinhua
# 样本: dangshen (4).jpg,被预测为:baihe
# 样本: dangshen (18).jpg,被预测为:baihe
# 样本: jinyinhua (112).jpg,被预测为:jinyinhua
# 样本: jinyinhua (130).jpg,被预测为:jinyinhua
# 样本: gouqi (3).jpg,被预测为:gouqi
# 样本: baihe (12).jpg,被预测为:baihe
# 样本: tianma (10).jpg,被预测为:baihe
# 样本: gouqi (5).jpg,被预测为:gouqi
# 样本: dangshen (3).jpg,被预测为:jinyinhua
# 样本: gouqi (8).jpg,被预测为:gouqi
# 样本: baihe (17).jpg,被预测为:baihe
# 样本: dangshen (2).jpg,被预测为:dangshen
# 样本: gouqi (2).jpg,被预测为:gouqi
# 样本: gouqi (7).gif,被预测为:gouqi
# 样本: tianma (14).jpg,被预测为:baihe
# 样本: dangshen (8).jpg,被预测为:dangshen
# 样本: baihe (19).jpg,被预测为:baihe
# 样本: baihe (6).jpg,被预测为:baihe
# 样本: jinyinhua (133).jpg,被预测为:jinyinhua
# 样本: gouqi (11).jpg,被预测为:gouqi
# 样本: jinyinhua (129).jpg,被预测为:jinyinhua
# 样本: dangshen (10).jpg,被预测为:dangshen
# 样本: jinyinhua (122).jpg,被预测为:jinyinhua
# 样本: jinyinhua (120).jpg,被预测为:jinyinhua
# 样本: gouqi (7).jpg,被预测为:gouqi
# 样本: tianma (15).jpg,被预测为:jinyinhua
# 样本: dangshen (13).jpg,被预测为:dangshen
